# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -90.000, high = 90.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve the data 
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]   
        city_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-pierre
# Processing Record 2 of Set 1 | olafsvik
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | taquari
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | iguape
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | mikhaylovka
# Processing Record 10 of Set 1 | ascope
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | yanam
# Processing Record 14 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 15 of Set 1 | niquero
# Processing Record 16 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | nuuk
# Processing Record 21 of Set 1 | beruwala
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | rawson
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | bukama
# Processing Record 27 of Set 1 | orocue
# Processing Record 28 of Set 1 | praia da vitoria
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | sao filipe
# Processing Record 31 of Set 1 | banda aceh
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | marsa matruh
# Processing Record 35 of Set 1 | fez
# Processing Record 36 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | comodoro rivadavia
# Processing Record 39 of Set 1 | bajo baudo
# City not found. Skipping...
# Processing Record 40 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 1 | aswan
# Processing Record 42 of Set 1 | mitu
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 1 | jacareacanga
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | mitsamiouli
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 2 | ostrovnoy
# Processing Record 3 of Set 2 | san-pedro
# Processing Record 4 of Set 2 | palmas
# Processing Record 5 of Set 2 | bardiyah
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | kochinda
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | plettenberg bay
# Processing Record 11 of Set 2 | aneho
# Processing Record 12 of Set 2 | lokosovo
# Processing Record 13 of Set 2 | oistins
# Processing Record 14 of Set 2 | yusva
# City not found. Skipping...
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | gravatai
# Processing Record 17 of Set 2 | novosil
# Processing Record 18 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 2 | beloha
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | alpena
# Processing Record 23 of Set 2 | attur
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | strezhevoy
# Processing Record 26 of Set 2 | adil-yangiyurt
# Processing Record 27 of Set 2 | saldanha
# Processing Record 28 of Set 2 | tiznit
# Processing Record 29 of Set 2 | calama
# Processing Record 30 of Set 2 | hwange
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | hambantota
# Processing Record 34 of Set 2 | atar
# Processing Record 35 of Set 2 | edea
# Processing Record 36 of Set 2 | puerto leguizamo
# Processing Record 37 of Set 2 | rafai
# Processing Record 38 of Set 2 | salmas
# Processing Record 39 of Set 2 | leticia
# Processing Record 40 of Set 2 | souillac
# Processing Record 41 of Set 2 | aquin
# Processing Record 42 of Set 2 | jutai
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | arvika
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | yei
# Processing Record 47 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 2 | mogadishu
# Processing Record 49 of Set 2 | codrington
# Processing Record 50 of Set 2 | jizan
# Processing Record 1 of Set 3 | porto walter
# Processing Record 2 of Set 3 | narsaq
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | sirfa
# City not found. Skipping...
# Processing Record 6 of Set 3 | salamiyah
# Processing Record 7 of Set 3 | saint-joseph
# Processing Record 8 of Set 3 | puerto del rosario
# Processing Record 9 of Set 3 | guarapari
# Processing Record 10 of Set 3 | kukuna
# Processing Record 11 of Set 3 | thornbury
# Processing Record 12 of Set 3 | sorland
# Processing Record 13 of Set 3 | bilma
# Processing Record 14 of Set 3 | oksfjord
# Processing Record 15 of Set 3 | vestmanna
# Processing Record 16 of Set 3 | bud
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | saint-augustin
# Processing Record 19 of Set 3 | palma
# Processing Record 20 of Set 3 | mizdah
# Processing Record 21 of Set 3 | marsh harbour
# Processing Record 22 of Set 3 | birao
# Processing Record 23 of Set 3 | sokoni
# Processing Record 24 of Set 3 | jibuti
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | panjab
# Processing Record 27 of Set 3 | boda
# Processing Record 28 of Set 3 | jalu
# Processing Record 29 of Set 3 | kirovohrad
# Processing Record 30 of Set 3 | sur
# Processing Record 31 of Set 3 | touros
# Processing Record 32 of Set 3 | inhambane
# Processing Record 33 of Set 3 | barcelos
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | amstetten
# Processing Record 36 of Set 3 | mahibadhoo
# Processing Record 37 of Set 3 | shahapur
# Processing Record 38 of Set 3 | loiza
# Processing Record 39 of Set 3 | mandera
# Processing Record 40 of Set 3 | el faiyum
# City not found. Skipping...
# Processing Record 41 of Set 3 | quatre cocos
# Processing Record 42 of Set 3 | cockburn town
# Processing Record 43 of Set 3 | cap-aux-meules
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | coquimbo
# Processing Record 46 of Set 3 | shelburne
# Processing Record 47 of Set 3 | polonnaruwa
# Processing Record 48 of Set 3 | novyy urengoy
# Processing Record 49 of Set 3 | ponta do sol
# Processing Record 50 of Set 3 | castro
# Processing Record 1 of Set 4 | omboue
# Processing Record 2 of Set 4 | dharan
# Processing Record 3 of Set 4 | robertsport
# Processing Record 4 of Set 4 | san andres
# Processing Record 5 of Set 4 | planaltina
# Processing Record 6 of Set 4 | skibbereen
# Processing Record 7 of Set 4 | marabba
# Processing Record 8 of Set 4 | petropavlovskoye
# Processing Record 9 of Set 4 | bara
# Processing Record 10 of Set 4 | rio grande
# Processing Record 11 of Set 4 | qaqortoq
# Processing Record 12 of Set 4 | saint-philippe
# Processing Record 13 of Set 4 | barra do garcas
# Processing Record 14 of Set 4 | namibe
# Processing Record 15 of Set 4 | dingle
# Processing Record 16 of Set 4 | shihezi
# Processing Record 17 of Set 4 | bandarbeyla
# Processing Record 18 of Set 4 | misratah
# Processing Record 19 of Set 4 | mopipi
# Processing Record 20 of Set 4 | morros
# Processing Record 21 of Set 4 | tyumentsevo
# Processing Record 22 of Set 4 | belmonte
# Processing Record 23 of Set 4 | sahbuz
# Processing Record 24 of Set 4 | lixourion
# Processing Record 25 of Set 4 | port said
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | lardos
# Processing Record 28 of Set 4 | lagoa
# Processing Record 29 of Set 4 | bambous virieux
# Processing Record 30 of Set 4 | camacha
# Processing Record 31 of Set 4 | luderitz
# Processing Record 32 of Set 4 | axim
# Processing Record 33 of Set 4 | sindor
# Processing Record 34 of Set 4 | muisne
# Processing Record 35 of Set 4 | novita
# Processing Record 36 of Set 4 | olavarria
# Processing Record 37 of Set 4 | dalton
# Processing Record 38 of Set 4 | minsk
# Processing Record 39 of Set 4 | caravelas
# Processing Record 40 of Set 4 | nalut
# Processing Record 41 of Set 4 | kaspiysk
# Processing Record 42 of Set 4 | santa fe
# Processing Record 43 of Set 4 | kashary
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | middleton
# Processing Record 46 of Set 4 | conceicao do araguaia
# Processing Record 47 of Set 4 | morant bay
# Processing Record 48 of Set 4 | faya
# Processing Record 49 of Set 4 | wrexham
# Processing Record 50 of Set 4 | gamba
# Processing Record 1 of Set 5 | abu samrah
# Processing Record 2 of Set 5 | chiredzi
# Processing Record 3 of Set 5 | nikolsk
# Processing Record 4 of Set 5 | alibag
# Processing Record 5 of Set 5 | arraial do cabo
# Processing Record 6 of Set 5 | rocky mount
# Processing Record 7 of Set 5 | mabaruma
# Processing Record 8 of Set 5 | manakara
# Processing Record 9 of Set 5 | abu kamal
# Processing Record 10 of Set 5 | yenagoa
# Processing Record 11 of Set 5 | himora
# City not found. Skipping...
# Processing Record 12 of Set 5 | tessalit
# Processing Record 13 of Set 5 | cascais
# Processing Record 14 of Set 5 | ati
# Processing Record 15 of Set 5 | clyde river
# Processing Record 16 of Set 5 | bonavista
# Processing Record 17 of Set 5 | roald
# Processing Record 18 of Set 5 | tabou
# Processing Record 19 of Set 5 | warnes
# Processing Record 20 of Set 5 | paamiut
# Processing Record 21 of Set 5 | shubarkuduk
# Processing Record 22 of Set 5 | dobryanka
# Processing Record 23 of Set 5 | pirgos
# Processing Record 24 of Set 5 | kotelnikovo
# Processing Record 25 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 26 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 5 | hofn
# Processing Record 28 of Set 5 | vestmannaeyjar
# Processing Record 29 of Set 5 | torquay
# Processing Record 30 of Set 5 | polistena
# Processing Record 31 of Set 5 | krasnoarmeysk
# Processing Record 32 of Set 5 | porto novo
# Processing Record 33 of Set 5 | dvorichna
# Processing Record 34 of Set 5 | mossendjo
# Processing Record 35 of Set 5 | grindavik
# Processing Record 36 of Set 5 | a
# City not found. Skipping...
# Processing Record 37 of Set 5 | leua
# Processing Record 38 of Set 5 | kalengwa
# Processing Record 39 of Set 5 | mahajanga
# Processing Record 40 of Set 5 | idah
# Processing Record 41 of Set 5 | macenta
# Processing Record 42 of Set 5 | kudahuvadhoo
# Processing Record 43 of Set 5 | krasnovishersk
# Processing Record 44 of Set 5 | marinette
# Processing Record 45 of Set 5 | iralaya
# Processing Record 46 of Set 5 | lapus
# Processing Record 47 of Set 5 | yangambi
# Processing Record 48 of Set 5 | bolshiye uki
# City not found. Skipping...
# Processing Record 49 of Set 5 | gazojak
# Processing Record 50 of Set 5 | kavaratti
# Processing Record 1 of Set 6 | marrakesh
# Processing Record 2 of Set 6 | tromso
# Processing Record 3 of Set 6 | touba
# Processing Record 4 of Set 6 | kiruna
# Processing Record 5 of Set 6 | mayumba
# Processing Record 6 of Set 6 | verkhnyaya inta
# Processing Record 7 of Set 6 | nanortalik
# Processing Record 8 of Set 6 | seidu
# Processing Record 9 of Set 6 | labrea
# Processing Record 10 of Set 6 | chipinge
# Processing Record 11 of Set 6 | tivoli
# Processing Record 12 of Set 6 | leh
# Processing Record 13 of Set 6 | husavik
# Processing Record 14 of Set 6 | prado
# Processing Record 15 of Set 6 | jardim
# Processing Record 16 of Set 6 | upata
# Processing Record 17 of Set 6 | lagos
# Processing Record 18 of Set 6 | marovoay
# Processing Record 19 of Set 6 | beyneu
# Processing Record 20 of Set 6 | vriezenveen
# Processing Record 21 of Set 6 | port-cartier
# Processing Record 22 of Set 6 | durban
# Processing Record 23 of Set 6 | kintampo
# Processing Record 24 of Set 6 | sakakah
# Processing Record 25 of Set 6 | alghero
# Processing Record 26 of Set 6 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 6 | angoche
# Processing Record 28 of Set 6 | rawah
# Processing Record 29 of Set 6 | rusape
# Processing Record 30 of Set 6 | chake chake
# Processing Record 31 of Set 6 | carutapera
# Processing Record 32 of Set 6 | hun
# Processing Record 33 of Set 6 | barreirinhas
# Processing Record 34 of Set 6 | zapolyarnyy
# Processing Record 35 of Set 6 | staroaleyskoye
# Processing Record 36 of Set 6 | akdepe
# Processing Record 37 of Set 6 | kidal
# Processing Record 38 of Set 6 | panaba
# Processing Record 39 of Set 6 | santa maria
# Processing Record 40 of Set 6 | east retford
# Processing Record 41 of Set 6 | sainte-marie
# Processing Record 42 of Set 6 | kabalo
# Processing Record 43 of Set 6 | saint-georges
# Processing Record 44 of Set 6 | bouna
# Processing Record 45 of Set 6 | rognan
# Processing Record 46 of Set 6 | kirkwall
# Processing Record 47 of Set 6 | takoradi
# Processing Record 48 of Set 6 | bocaranga
# City not found. Skipping...
# Processing Record 49 of Set 6 | rincon
# Processing Record 50 of Set 6 | kavant
# City not found. Skipping...
# Processing Record 1 of Set 7 | turukhansk
# Processing Record 2 of Set 7 | sao paulo do potengi
# Processing Record 3 of Set 7 | jagodina
# Processing Record 4 of Set 7 | mangrol
# Processing Record 5 of Set 7 | grand gaube
# Processing Record 6 of Set 7 | mint hill
# Processing Record 7 of Set 7 | reconquista
# Processing Record 8 of Set 7 | boa vista
# Processing Record 9 of Set 7 | arlit
# Processing Record 10 of Set 7 | doha
# Processing Record 11 of Set 7 | westfield
# Processing Record 12 of Set 7 | adrar
# Processing Record 13 of Set 7 | le port
# Processing Record 14 of Set 7 | korla
# Processing Record 15 of Set 7 | hamilton
# Processing Record 16 of Set 7 | alindao
# Processing Record 17 of Set 7 | walvis bay
# Processing Record 18 of Set 7 | belyy yar
# Processing Record 19 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 7 | laguna
# Processing Record 21 of Set 7 | mwene-ditu
# Processing Record 22 of Set 7 | antofagasta
# Processing Record 23 of Set 7 | macapa
# Processing Record 24 of Set 7 | boende
# Processing Record 25 of Set 7 | sherbakul
# Processing Record 26 of Set 7 | pombas
# Processing Record 27 of Set 7 | paramonga
# Processing Record 28 of Set 7 | mehamn
# Processing Record 29 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 7 | bubaque
# Processing Record 31 of Set 7 | hammerfest
# Processing Record 32 of Set 7 | nizwa
# Processing Record 33 of Set 7 | bela vista de goias
# Processing Record 34 of Set 7 | betsiamites
# Processing Record 35 of Set 7 | kharan
# Processing Record 36 of Set 7 | portree
# Processing Record 37 of Set 7 | rivadavia
# Processing Record 38 of Set 7 | bayji
# Processing Record 39 of Set 7 | hargeysa
# Processing Record 40 of Set 7 | hakkari
# Processing Record 41 of Set 7 | baghdad
# Processing Record 42 of Set 7 | kumluca
# Processing Record 43 of Set 7 | sao jose da coroa grande
# Processing Record 44 of Set 7 | garowe
# Processing Record 45 of Set 7 | radviliskis
# Processing Record 46 of Set 7 | pinheiro machado
# Processing Record 47 of Set 7 | carnarvon
# Processing Record 48 of Set 7 | pitea
# Processing Record 49 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 50 of Set 7 | otradnaya
# Processing Record 1 of Set 8 | raudeberg
# Processing Record 2 of Set 8 | saint-paul
# Processing Record 3 of Set 8 | damietta
# Processing Record 4 of Set 8 | elliot lake
# Processing Record 5 of Set 8 | pamplona
# Processing Record 6 of Set 8 | asfi
# Processing Record 7 of Set 8 | kasongo-lunda
# Processing Record 8 of Set 8 | benicarlo
# Processing Record 9 of Set 8 | nicoya
# Processing Record 10 of Set 8 | sioux lookout
# Processing Record 11 of Set 8 | ornskoldsvik
# Processing Record 12 of Set 8 | chicama
# Processing Record 13 of Set 8 | barranca
# Processing Record 14 of Set 8 | san antonio
# Processing Record 15 of Set 8 | mongu
# Processing Record 16 of Set 8 | kargasok
# Processing Record 17 of Set 8 | gat
# Processing Record 18 of Set 8 | oranjemund
# Processing Record 19 of Set 8 | neyshabur
# Processing Record 20 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 8 | syasstroy
# Processing Record 22 of Set 8 | bari
# Processing Record 23 of Set 8 | uruguaiana
# Processing Record 24 of Set 8 | placido de castro
# Processing Record 25 of Set 8 | aktau
# Processing Record 26 of Set 8 | trairi
# Processing Record 27 of Set 8 | santa cruz
# Processing Record 28 of Set 8 | valparaiso
# Processing Record 29 of Set 8 | guadalajara
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 8 | vila franca do campo
# Processing Record 33 of Set 8 | gunjur
# Processing Record 34 of Set 8 | fuente de oro
# Processing Record 35 of Set 8 | opole
# Processing Record 36 of Set 8 | itarema
# Processing Record 37 of Set 8 | thompson
# Processing Record 38 of Set 8 | kemijarvi
# Processing Record 39 of Set 8 | taoudenni
# Processing Record 40 of Set 8 | turmalina
# Processing Record 41 of Set 8 | druzhba
# Processing Record 42 of Set 8 | ratnagiri
# Processing Record 43 of Set 8 | hommelvik
# Processing Record 44 of Set 8 | bathsheba
# Processing Record 45 of Set 8 | tortoli
# Processing Record 46 of Set 8 | kapiri mposhi
# Processing Record 47 of Set 8 | berlevag
# Processing Record 48 of Set 8 | santarem
# Processing Record 49 of Set 8 | requena
# Processing Record 50 of Set 8 | odweyne
# Processing Record 1 of Set 9 | nouadhibou
# Processing Record 2 of Set 9 | tiradentes
# Processing Record 3 of Set 9 | doische
# Processing Record 4 of Set 9 | nepalganj
# City not found. Skipping...
# Processing Record 5 of Set 9 | blytheville
# Processing Record 6 of Set 9 | santa rosa
# Processing Record 7 of Set 9 | kungalv
# Processing Record 8 of Set 9 | nicosia
# Processing Record 9 of Set 9 | nova aurora
# Processing Record 10 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 9 | maniwaki
# Processing Record 12 of Set 9 | urdoma
# Processing Record 13 of Set 9 | raga
# Processing Record 14 of Set 9 | sao joao da barra
# Processing Record 15 of Set 9 | pangnirtung
# Processing Record 16 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 17 of Set 9 | aranos
# Processing Record 18 of Set 9 | bennington
# Processing Record 19 of Set 9 | labytnangi
# Processing Record 20 of Set 9 | staryy nadym
# Processing Record 21 of Set 9 | zheleznodorozhnyy
# Processing Record 22 of Set 9 | obligado
# Processing Record 23 of Set 9 | ugoofaaru
# Processing Record 24 of Set 9 | marawi
# Processing Record 25 of Set 9 | ubinskoye
# Processing Record 26 of Set 9 | usak
# Processing Record 27 of Set 9 | ambilobe
# Processing Record 28 of Set 9 | urubicha
# Processing Record 29 of Set 9 | rock hill
# Processing Record 30 of Set 9 | gandajika
# Processing Record 31 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 9 | avallon
# Processing Record 33 of Set 9 | khandbari
# Processing Record 34 of Set 9 | camocim
# Processing Record 35 of Set 9 | charagua
# Processing Record 36 of Set 9 | cravo norte
# Processing Record 37 of Set 9 | amapa
# Processing Record 38 of Set 9 | atbasar
# Processing Record 39 of Set 9 | scarborough
# Processing Record 40 of Set 9 | antsohihy
# Processing Record 41 of Set 9 | volosovo
# Processing Record 42 of Set 9 | tahta
# Processing Record 43 of Set 9 | bayburt
# Processing Record 44 of Set 9 | huarmey
# Processing Record 45 of Set 9 | necochea
# Processing Record 46 of Set 9 | jeremie
# Processing Record 47 of Set 9 | pontal do parana
# Processing Record 48 of Set 9 | ust-kan
# Processing Record 49 of Set 9 | entre rios
# Processing Record 50 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 1 of Set 10 | manyana
# Processing Record 2 of Set 10 | ariquemes
# Processing Record 3 of Set 10 | itamaraca
# Processing Record 4 of Set 10 | viedma
# Processing Record 5 of Set 10 | lyantonde
# Processing Record 6 of Set 10 | brae
# Processing Record 7 of Set 10 | qurayyat
# Processing Record 8 of Set 10 | oktyabrskoye
# Processing Record 9 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 10 | mudbidri
# Processing Record 11 of Set 10 | mathathane
# Processing Record 12 of Set 10 | rafaela
# Processing Record 13 of Set 10 | masunga
# Processing Record 14 of Set 10 | esmeraldas
# Processing Record 15 of Set 10 | port shepstone
# Processing Record 16 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 10 | ascension
# Processing Record 18 of Set 10 | sao gabriel da cachoeira
# Processing Record 19 of Set 10 | kedrovyy
# Processing Record 20 of Set 10 | cruden bay
# City not found. Skipping...
# Processing Record 21 of Set 10 | gualaquiza
# Processing Record 22 of Set 10 | areia branca
# Processing Record 23 of Set 10 | uusikaupunki
# Processing Record 24 of Set 10 | muzhi
# Processing Record 25 of Set 10 | nisia floresta
# Processing Record 26 of Set 10 | caucaia
# Processing Record 27 of Set 10 | nanga eboko
# Processing Record 28 of Set 10 | senneterre
# Processing Record 29 of Set 10 | madison
# Processing Record 30 of Set 10 | balkanabat
# Processing Record 31 of Set 10 | yayva
# Processing Record 32 of Set 10 | lerum
# Processing Record 33 of Set 10 | kapoeta
# Processing Record 34 of Set 10 | rocha
# Processing Record 35 of Set 10 | poli
# Processing Record 36 of Set 10 | gualeguaychu
# Processing Record 37 of Set 10 | sangueya
# Processing Record 38 of Set 10 | qostanay
# Processing Record 39 of Set 10 | varhaug
# Processing Record 40 of Set 10 | andros town
# Processing Record 41 of Set 10 | vila velha
# Processing Record 42 of Set 10 | mufulira
# Processing Record 43 of Set 10 | cabedelo
# Processing Record 44 of Set 10 | alto araguaia
# Processing Record 45 of Set 10 | marquette
# Processing Record 46 of Set 10 | beira
# Processing Record 47 of Set 10 | mpophomeni
# Processing Record 48 of Set 10 | doka
# Processing Record 49 of Set 10 | tsentralnyy
# City not found. Skipping...
# Processing Record 50 of Set 10 | santa isabel do rio negro
# Processing Record 1 of Set 11 | ponta delgada
# Processing Record 2 of Set 11 | kumta
# Processing Record 3 of Set 11 | chakrata
# Processing Record 4 of Set 11 | elizabeth city
# Processing Record 5 of Set 11 | makokou
# Processing Record 6 of Set 11 | bayir
# Processing Record 7 of Set 11 | ardabil
# Processing Record 8 of Set 11 | chlorakas
# Processing Record 9 of Set 11 | sabha
# Processing Record 10 of Set 11 | mafinga
# Processing Record 11 of Set 11 | gazanjyk
# Processing Record 12 of Set 11 | hobyo
# Processing Record 13 of Set 11 | sao lourenco do sul
# Processing Record 14 of Set 11 | clarence town
# Processing Record 15 of Set 11 | goiatuba
# Processing Record 16 of Set 11 | vale da amoreira
# Processing Record 17 of Set 11 | machinga
# Processing Record 18 of Set 11 | yarada
# Processing Record 19 of Set 11 | macau
# Processing Record 20 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 11 | bengkulu
# Processing Record 22 of Set 11 | namikupa
# Processing Record 23 of Set 11 | gwadar
# Processing Record 24 of Set 11 | bohicon
# Processing Record 25 of Set 11 | manta
# Processing Record 26 of Set 11 | narovchat
# Processing Record 27 of Set 11 | alanya
# Processing Record 28 of Set 11 | mikhaylov
# Processing Record 29 of Set 11 | mana
# Processing Record 30 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 31 of Set 11 | kuhestan
# City not found. Skipping...
# Processing Record 32 of Set 11 | sao bento do sul
# Processing Record 33 of Set 11 | otjiwarongo
# Processing Record 34 of Set 11 | salinas
# Processing Record 35 of Set 11 | baraboo
# Processing Record 36 of Set 11 | saint-francois
# Processing Record 37 of Set 11 | zheshart
# Processing Record 38 of Set 11 | menzelinsk
# Processing Record 39 of Set 11 | dingolfing
# Processing Record 40 of Set 11 | douentza
# Processing Record 41 of Set 11 | villa maria
# Processing Record 42 of Set 11 | mafra
# Processing Record 43 of Set 11 | banfora
# Processing Record 44 of Set 11 | westport
# Processing Record 45 of Set 11 | pavlodar
# Processing Record 46 of Set 11 | campoverde
# Processing Record 47 of Set 11 | curepipe
# Processing Record 48 of Set 11 | derzhavinsk
# Processing Record 49 of Set 11 | port blair
# Processing Record 50 of Set 11 | stephenville crossing
# Processing Record 1 of Set 12 | pisco
# Processing Record 2 of Set 12 | bozoum
# Processing Record 3 of Set 12 | kingseat
# Processing Record 4 of Set 12 | kutum
# Processing Record 5 of Set 12 | harer
# Processing Record 6 of Set 12 | kautokeino
# Processing Record 7 of Set 12 | canto do buriti
# Processing Record 8 of Set 12 | sarh
# Processing Record 9 of Set 12 | juba
# Processing Record 10 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 12 | sovetskaya
# Processing Record 12 of Set 12 | ewo
# Processing Record 13 of Set 12 | flores da cunha
# Processing Record 14 of Set 12 | alta floresta
# Processing Record 15 of Set 12 | camp springs
# Processing Record 16 of Set 12 | stornoway
# Processing Record 17 of Set 12 | picayune
# Processing Record 18 of Set 12 | kahta
# Processing Record 19 of Set 12 | kardla
# Processing Record 20 of Set 12 | edd
# Processing Record 21 of Set 12 | stokmarknes
# Processing Record 22 of Set 12 | paracuru
# Processing Record 23 of Set 12 | kourou
# Processing Record 24 of Set 12 | lusambo
# Processing Record 25 of Set 12 | illapel
# Processing Record 26 of Set 12 | san carlos de bariloche
# Processing Record 27 of Set 12 | kurchum
# Processing Record 28 of Set 12 | trelew
# Processing Record 29 of Set 12 | riyadh
# Processing Record 30 of Set 12 | escanaba
# Processing Record 31 of Set 12 | rudnichnyy
# Processing Record 32 of Set 12 | chimbote
# Processing Record 33 of Set 12 | yar-sale
# Processing Record 34 of Set 12 | kasur
# Processing Record 35 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 12 | margate
# Processing Record 37 of Set 12 | barra patuca
# Processing Record 38 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 39 of Set 12 | bafoulabe
# Processing Record 40 of Set 12 | mapiripan
# Processing Record 41 of Set 12 | syracuse
# Processing Record 42 of Set 12 | destin
# Processing Record 43 of Set 12 | sitio novo do tocantins
# Processing Record 44 of Set 12 | kuytun
# Processing Record 45 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 46 of Set 12 | karaton
# Processing Record 47 of Set 12 | thinadhoo
# Processing Record 48 of Set 12 | milledgeville
# Processing Record 49 of Set 12 | muskegon
# Processing Record 50 of Set 12 | severnyy
# Processing Record 1 of Set 13 | meulaboh
# Processing Record 2 of Set 13 | los llanos de aridane
# Processing Record 3 of Set 13 | maun
# Processing Record 4 of Set 13 | iquitos
# Processing Record 5 of Set 13 | ampanihy
# Processing Record 6 of Set 13 | bumba
# Processing Record 7 of Set 13 | muravlenko
# Processing Record 8 of Set 13 | richards bay
# Processing Record 9 of Set 13 | gari
# Processing Record 10 of Set 13 | halifax
# Processing Record 11 of Set 13 | nurota
# Processing Record 12 of Set 13 | buraydah
# Processing Record 13 of Set 13 | mahdalynivka
# Processing Record 14 of Set 13 | spodnja idrija
# Processing Record 15 of Set 13 | yining
# Processing Record 16 of Set 13 | matara
# Processing Record 17 of Set 13 | zhezkazgan
# Processing Record 18 of Set 13 | muros
# Processing Record 19 of Set 13 | dunmore town
# Processing Record 20 of Set 13 | maxcanu
# Processing Record 21 of Set 13 | arak
# Processing Record 22 of Set 13 | olinda
# Processing Record 23 of Set 13 | fernandina beach
# Processing Record 24 of Set 13 | pascagoula
# Processing Record 25 of Set 13 | rock sound
# Processing Record 26 of Set 13 | lamu
# Processing Record 27 of Set 13 | chiquimula
# Processing Record 28 of Set 13 | zdvinsk
# Processing Record 29 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 30 of Set 13 | artvin
# Processing Record 31 of Set 13 | krasnaya gora
# Processing Record 32 of Set 13 | nantucket
# Processing Record 33 of Set 13 | bhakkar
# Processing Record 34 of Set 13 | uthal
# Processing Record 35 of Set 13 | lesnoye
# Processing Record 36 of Set 13 | torgelow
# Processing Record 37 of Set 13 | priboj
# Processing Record 38 of Set 13 | praia
# Processing Record 39 of Set 13 | nioro
# Processing Record 40 of Set 13 | lasa
# Processing Record 41 of Set 13 | luanda
# Processing Record 42 of Set 13 | umm lajj
# Processing Record 43 of Set 13 | crotone
# Processing Record 44 of Set 13 | sambava
# Processing Record 45 of Set 13 | zaraza
# Processing Record 46 of Set 13 | bodden town
# Processing Record 47 of Set 13 | sayyan
# Processing Record 48 of Set 13 | albany
# Processing Record 49 of Set 13 | ancud
# Processing Record 50 of Set 13 | jedrzejow
# Processing Record 1 of Set 14 | pimenta bueno
# Processing Record 2 of Set 14 | pskov
# Processing Record 3 of Set 14 | tazovskiy
# Processing Record 4 of Set 14 | ajdabiya
# Processing Record 5 of Set 14 | de aar
# Processing Record 6 of Set 14 | kindu
# Processing Record 7 of Set 14 | liptovsky hradok
# Processing Record 8 of Set 14 | araouane
# Processing Record 9 of Set 14 | idlib
# Processing Record 10 of Set 14 | matam
# Processing Record 11 of Set 14 | harper
# Processing Record 12 of Set 14 | machico
# Processing Record 13 of Set 14 | san jose
# Processing Record 14 of Set 14 | dakar
# Processing Record 15 of Set 14 | suoyarvi
# Processing Record 16 of Set 14 | pyaozerskiy
# Processing Record 17 of Set 14 | meridian
# Processing Record 18 of Set 14 | rameswaram
# Processing Record 19 of Set 14 | hareid
# Processing Record 20 of Set 14 | kissidougou
# Processing Record 21 of Set 14 | pitimbu
# Processing Record 22 of Set 14 | estelle
# Processing Record 23 of Set 14 | buenos aires
# Processing Record 24 of Set 14 | marfino
# Processing Record 25 of Set 14 | lerwick
# Processing Record 26 of Set 14 | kambove
# Processing Record 27 of Set 14 | penzance
# Processing Record 28 of Set 14 | bonthe
# Processing Record 29 of Set 14 | paidha
# Processing Record 30 of Set 14 | san pedro
# Processing Record 31 of Set 14 | tukrah
# Processing Record 32 of Set 14 | semey
# Processing Record 33 of Set 14 | havre-saint-pierre
# Processing Record 34 of Set 14 | inirida
# Processing Record 35 of Set 14 | merritt island
# Processing Record 36 of Set 14 | benoy
# Processing Record 37 of Set 14 | chapais
# Processing Record 38 of Set 14 | kuntaur
# Processing Record 39 of Set 14 | waynesboro
# Processing Record 40 of Set 14 | kinshasa
# Processing Record 41 of Set 14 | iskitim
# Processing Record 42 of Set 14 | nexo
# Processing Record 43 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 14 | santa marta
# Processing Record 45 of Set 14 | camana
# Processing Record 46 of Set 14 | lohja
# Processing Record 47 of Set 14 | sept-iles
# Processing Record 48 of Set 14 | capim grosso
# Processing Record 49 of Set 14 | sistranda
# Processing Record 50 of Set 14 | maceio
# Processing Record 1 of Set 15 | les escoumins
# Processing Record 2 of Set 15 | miraflores
# Processing Record 3 of Set 15 | wagrowiec
# Processing Record 4 of Set 15 | serramanna
# Processing Record 5 of Set 15 | viseu
# Processing Record 6 of Set 15 | aksu
# Processing Record 7 of Set 15 | menongue
# Processing Record 8 of Set 15 | mweka
# Processing Record 9 of Set 15 | antalaha
# Processing Record 10 of Set 15 | libourne
# Processing Record 11 of Set 15 | saint anthony
# Processing Record 12 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 14 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 15 | georgiyevka
# Processing Record 16 of Set 15 | zhashkiv
# Processing Record 17 of Set 15 | puerto ayacucho
# Processing Record 18 of Set 15 | nitchidorf
# Processing Record 19 of Set 15 | achisay
# City not found. Skipping...
# Processing Record 20 of Set 15 | dudinka
# Processing Record 21 of Set 15 | mugla
# Processing Record 22 of Set 15 | forio
# Processing Record 23 of Set 15 | stamsund
# City not found. Skipping...
# Processing Record 24 of Set 15 | aras
# Processing Record 25 of Set 15 | santiago del estero
# Processing Record 26 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 27 of Set 15 | kilindoni
# Processing Record 28 of Set 15 | opuwo
# Processing Record 29 of Set 15 | mahanoro
# Processing Record 30 of Set 15 | kulhudhuffushi
# Processing Record 31 of Set 15 | dona ines
# Processing Record 32 of Set 15 | ilo
# Processing Record 33 of Set 15 | dipkarpaz
# City not found. Skipping...
# Processing Record 34 of Set 15 | cauquenes
# Processing Record 35 of Set 15 | bam
# Processing Record 36 of Set 15 | lurgan
# Processing Record 37 of Set 15 | dvinskoy
# Processing Record 38 of Set 15 | sechura
# Processing Record 39 of Set 15 | malanje
# Processing Record 40 of Set 15 | kwekwe
# Processing Record 41 of Set 15 | sinazongwe
# Processing Record 42 of Set 15 | sal rei
# Processing Record 43 of Set 15 | sandwick
# Processing Record 44 of Set 15 | pangody
# Processing Record 45 of Set 15 | mgandu
# Processing Record 46 of Set 15 | karasburg
# Processing Record 47 of Set 15 | selfoss
# Processing Record 48 of Set 15 | pedernales
# Processing Record 49 of Set 15 | perigueux
# Processing Record 50 of Set 15 | dharchula
# Processing Record 1 of Set 16 | znamenskoye
# Processing Record 2 of Set 16 | neka
# Processing Record 3 of Set 16 | bichena
# Processing Record 4 of Set 16 | evanston
# Processing Record 5 of Set 16 | vesele
# Processing Record 6 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 16 | colares
# Processing Record 8 of Set 16 | chingirlau
# Processing Record 9 of Set 16 | tafalla
# Processing Record 10 of Set 16 | dalkola
# Processing Record 11 of Set 16 | acarau
# Processing Record 12 of Set 16 | zhanatas
# City not found. Skipping...
# Processing Record 13 of Set 16 | sanok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Saint-Pierre -21.3393  55.4781     78.91        61           0       18.41
# 1      Olafsvik  64.8945 -23.7142     37.18        78          56        8.25
# 2   Port Alfred -33.5906  26.8910     70.57        80         100        7.52
# 3     Hithadhoo  -0.6000  73.0833     80.80        71          97        9.06
# 4       Taquari -29.7997 -51.8644     64.33        96          54        1.52
# 5  Kruisfontein -34.0033  24.7314     64.89        80         100        7.54
# 6        Iguape -24.7081 -47.5553     66.88        95          27        3.62
# 7     Cape Town -33.9258  18.4232     63.12        86          75       12.66
# 8   Mikhaylovka  50.0600  43.2379     35.71        66           0        2.73
# 9        Ascope  -7.7144 -79.1078     56.53        78          72        3.00
#
#   Country Current Description
# 0      RE           clear sky
# 1      IS       broken clouds
# 2      ZA     overcast clouds
# 3      MV     overcast clouds
# 4      BR       broken clouds
# 5      ZA          light rain
# 6      BR    scattered clouds
# 7      ZA       broken clouds
# 8      RU           clear sky
# 9      PE       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Pierre      RE -21.3393  55.4781     78.91        61           0
# 1      Olafsvik      IS  64.8945 -23.7142     37.18        78          56
# 2   Port Alfred      ZA -33.5906  26.8910     70.57        80         100
# 3     Hithadhoo      MV  -0.6000  73.0833     80.80        71          97
# 4       Taquari      BR -29.7997 -51.8644     64.33        96          54
# 5  Kruisfontein      ZA -34.0033  24.7314     64.89        80         100
# 6        Iguape      BR -24.7081 -47.5553     66.88        95          27
# 7     Cape Town      ZA -33.9258  18.4232     63.12        86          75
# 8   Mikhaylovka      RU  50.0600  43.2379     35.71        66           0
# 9        Ascope      PE  -7.7144 -79.1078     56.53        78          72
#
#    Wind Speed Current Description
# 0       18.41           clear sky
# 1        8.25       broken clouds
# 2        7.52     overcast clouds
# 3        9.06     overcast clouds
# 4        1.52       broken clouds
# 5        7.54          light rain
# 6        3.62    scattered clouds
# 7       12.66       broken clouds
# 8        2.73           clear sky
# 9        3.00       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = '../Weather_Database/WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
